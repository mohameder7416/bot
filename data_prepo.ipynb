# %%
import csv

vehicles = [
  {
    "vin": "1HGCM82633A123456",
    "year": 2022,
    "make": "Honda",
    "model": "Civic",
    "isadded": True,
    "mileage": 15000,
    "condition": "new",
    "title": "clean title",
    "price": 25000,
    "price_type": "cash"
  },
  {
    "vin": "1FTRX18L5YNA12345",
    "year": 2020,
    "make": "Ford",
    "model": "F-150",
    "isadded": True,
    "mileage": 30000,
    "condition": "old",
    "title": "clean title",
    "price": 35000,
    "price_type": "downpayment"
  },
  {
    "vin": "2T1BURHE0GC123456",
    "year": 2018,
    "make": "Toyota",
    "model": "Corolla",
    "isadded": False,
    "mileage": 45000,
    "condition": "old",
    "title": "rebuilt",
    "price": 15000,
    "price_type": "cash"
  },
  {
    "vin": "3VWDB7AJ0EM123456",
    "year": 2021,
    "make": "Volkswagen",
    "model": "Jetta",
    "isadded": True,
    "mileage": 12000,
    "condition": "new",
    "title": "clean title",
    "price": 23000,
    "price_type": "downpayment"
  },
  {
    "vin": "5XYKT3A63EG123456",
    "year": 2019,
    "make": "Kia",
    "model": "Sorento",
    "isadded": False,
    "mileage": 20000,
    "condition": "old",
    "title": "clean title",
    "price": 27000,
    "price_type": "cash"
  },
  {
    "vin": "1C6RR7FT3JS123456",
    "year": 2020,
    "make": "Ram",
    "model": "1500",
    "isadded": True,
    "mileage": 18000,
    "condition": "new",
    "title": "clean title",
    "price": 42000,
    "price_type": "downpayment"
  },
  {
    "vin": "4S4BMBKQ9G3301234",
    "year": 2022,
    "make": "Subaru",
    "model": "Outback",
    "isadded": True,
    "mileage": 5000,
    "condition": "new",
    "title": "clean title",
    "price": 35000,
    "price_type": "cash"
  },
  {
    "vin": "3GNAXUEV0LS123456",
    "year": 2020,
    "make": "Chevrolet",
    "model": "Equinox",
    "isadded": False,
    "mileage": 25000,
    "condition": "old",
    "title": "clean title",
    "price": 22000,
    "price_type": "downpayment"
  },
  {
    "vin": "1FMCU9G99LUC12345",
    "year": 2021,
    "make": "Ford",
    "model": "Escape",
    "isadded": True,
    "mileage": 10000,
    "condition": "new",
    "title": "clean title",
    "price": 28000,
    "price_type": "cash"
  },
  {
    "vin": "1FTEX1C87GKE12345",
    "year": 2021,
    "make": "Ford",
    "model": "Ranger",
    "isadded": True,
    "mileage": 9000,
    "condition": "new",
    "title": "clean title",
    "price": 35000,
    "price_type": "cash"
  },
  {
    "vin": "1GT12YEG9FZ123456",
    "year": 2019,
    "make": "GMC",
    "model": "Sierra 1500",
    "isadded": False,
    "mileage": 40000,
    "condition": "old",
    "title": "rebuilt",
    "price": 28000,
    "price_type": "downpayment"
  },
  {
    "vin": "1C4PJMCX1LD123456",
    "year": 2020,
    "make": "Jeep",
    "model": "Cherokee",
    "isadded": True,
    "mileage": 22000,
    "condition": "old",
    "title": "clean title",
    "price": 27000,
    "price_type": "cash"
  },
  {
    "vin": "5N1AT2MT5HC123456",
    "year": 2021,
    "make": "Nissan",
    "model": "Rogue",
    "isadded": True,
    "mileage": 8000,
    "condition": "new",
    "title": "clean title",
    "price": 32000,
    "price_type": "downpayment"
  },
  {
    "vin": "2T3WFREV1KW123456",
    "year": 2022,
    "make": "Toyota",
    "model": "RAV4",
    "isadded": True,
    "mileage": 12000,
    "condition": "new",
    "title": "clean title",
    "price": 35000,
    "price_type": "cash"
  },
  {
    "vin": "5TFLU4EN0EX123456",
    "year": 2020,
    "make": "Toyota",
    "model": "Tacoma",
    "isadded": False,
    "mileage": 50000,
    "condition": "old",
    "title": "clean title",
    "price": 30000,
    "price_type": "downpayment"
  },
  {
    "vin": "1GTN1LEXXLZ123456",
    "year": 2021,
    "make": "GMC",
    "model": "Canyon",
    "isadded": True,
    "mileage": 7000,
    "condition": "new",
    "title": "clean title",
    "price": 35000,
    "price_type": "cash"
  },
  {
    "vin": "3VV3B7AX9LM123456",
    "year": 2022,
    "make": "Volkswagen",
    "model": "Atlas",
    "isadded": True,
    "mileage": 10000,
    "condition": "new",
    "title": "clean title",
    "price": 45000,
    "price_type": "cash"
  },
  {
    "vin": "1J4GB2XG1YW123456",
    "year": 2019,
    "make": "Jeep",
    "model": "Grand Cherokee",
    "isadded": False,
    "mileage": 35000,
    "condition": "old",
    "title": "clean title",
    "price": 29000,
    "price_type": "downpayment"
  },
  {
    "vin": "1FMZU7D57LUB12345",
    "year": 2020,
    "make": "Ford",
    "model": "Explorer",
    "isadded": True,
    "mileage": 8000,
    "condition": "new",
    "title": "clean title",
    "price": 37000,
    "price_type": "cash"
  }
]

# Define CSV column headers in desired order
fieldnames = [
    "vin",
    "year",
    "make",
    "model",
    "isadded",
    "mileage",
    "condition",
    "title",
    "price",
    "price_type"
]

# Write to CSV file
with open("vehicles.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(vehicles)

print("CSV file created successfully: vehicles.csv")
# Out:
# CSV file created successfully: vehicles.csv
